# %% [markdown]
# ## MICE
# Utiliser MICE (Multiple Imputation by Chained Equations)  pour imputer les valeurs manquante.
#
# **Objectif** :
# * Vérifier si les conditions d'une bonne convergence est respectées
# * Utiliser **MICE**pour imputer les valeurs manquantes.
# * Comparer les distributions avant et après imputation
# * Comparer les éléments statistique avant et après imputation
# Vous pouvez trouver la documentation ici [MICE](https://www.statsmodels.org/stable/generated/statsmodels.imputation.mice.MICE.html).s

# %% [markdown]
# ### Librairies & warnings contrôle

# %%
import pandas as pd
import numpy as np
from statsmodels.imputation import mice
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import missingno as misno

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Fonction pour la visualisation avant et après l'imputation

# %%
def ajust_graph():
    plt.subplots_adjust(left=0,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.6)

# %%
def plot_dist(data, color = 'none', n_col = 3, n_rows = 2) :
    
    """Permet d'affcher des distribution
    de plusieurs variables numeriques
    avant une meilleurs mise en forme"""
    
    df_numeric = data.select_dtypes(include =['float', 'int'])
    for i, col in tqdm(enumerate(df_numeric)):
        plt.subplot(n_rows, n_col, i+1)
        ajust_graph()
        sns.distplot(df_numeric[col], color = color, hist = False, label = f"{col}" if color == 'red' else f"{col}_imputed" )
        plt.title(f"Distribution observée : {col}", fontsize =10)
        plt.legend(loc = 'best')
        plt.xlabel('variable')
        plt.grid(True)

# %% [markdown]
# ### Chargeemt et lecture du dataset

# %%
use_cols = ['VILLE', 'NOMBRE_ETUDIANTS', 'AGE_ENTREE', 
 'COUT_MOYEN_ANNEE_ACADEMIE', 'TAUX_ADMISSION', "DEFAUT_PAIEMENT_2ANNEES",
           'DEFAUT_PAIEMENT_3ANNEES']

# %%
df = pd.read_csv("data.csv", usecols = use_cols).sample(n = 300,random_state =0)

# %%
df. head(3)
# Out:
#                  VILLE NOMBRE_ETUDIANTS    AGE_ENTREE  \
# 6747           Houston            13484  33.360801106
# 3687           Beckley             5340   20.54234904
# 5625  Santa Fe Springs               37  28.626666667
#
#       COUT_MOYEN_ANNEE_ACADEMIE  TAUX_ADMISSION  DEFAUT_PAIEMENT_2ANNEES  \
# 6747                        NaN             NaN                    0.105
# 3687                    17166.0          0.6065                    0.086
# 5625                        NaN             NaN                    0.000
#
#       DEFAUT_PAIEMENT_3ANNEES
# 6747                    0.104
# 3687                    0.080
# 5625                    0.190

# %%
df.shape
# Out:
# (300, 7)

# %%
((df.isna().sum()/ df.shape[0])*100).sort_values()
# Out:
# VILLE                         0.000000
# NOMBRE_ETUDIANTS              4.666667
# AGE_ENTREE                    7.333333
# DEFAUT_PAIEMENT_3ANNEES      18.000000
# DEFAUT_PAIEMENT_2ANNEES      19.333333
# COUT_MOYEN_ANNEE_ACADEMIE    52.333333
# TAUX_ADMISSION               72.000000
# dtype: float64

# %% [markdown]
# ### Vérification de linéarité ou non-linéarité

# %%
sns.pairplot(df, height = 1.7)

# %% [markdown]
# #### Commentaire
#
# * Nos variable ne sont ni fortement linéaire (i.e les points ne suivent pas la première bissectrice) ni fortement non-linéaire (genre les points ne suivent une fonction sinusoidale de nveau 1).
#
# * Parmi nos variable, il y'a 2 dont le taux de valeurs maquantes est très élevé ( plus de 50% ).
#
# * Nous allons donc appliquer le fameux  MICE pour imputer les nan et tirer une conclusion sur le niveau de précision.

# %% [markdown]
# ### Imputation avec MICE

# %%
df.dtypes
# Out:
# VILLE                         object
# NOMBRE_ETUDIANTS              object
# AGE_ENTREE                    object
# COUT_MOYEN_ANNEE_ACADEMIE    float64
# TAUX_ADMISSION               float64
# DEFAUT_PAIEMENT_2ANNEES      float64
# DEFAUT_PAIEMENT_3ANNEES      float64
# dtype: object

# %%
df.loc[df["AGE_ENTREE"]=='PrivacySuppressed', :]
# Out:
#               VILLE   NOMBRE_ETUDIANTS         AGE_ENTREE  \
# 202   San Francisco  PrivacySuppressed  PrivacySuppressed
# 3287        Houston  PrivacySuppressed  PrivacySuppressed
# 5467    Kailua Kona  PrivacySuppressed  PrivacySuppressed
# 3225      Nashville  PrivacySuppressed  PrivacySuppressed
# 5047         Denver  PrivacySuppressed  PrivacySuppressed
# 4542      Wadesboro  PrivacySuppressed  PrivacySuppressed
# 311        Berkeley                NaN  PrivacySuppressed
# 296      Santa Cruz  PrivacySuppressed  PrivacySuppressed
#
#       COUT_MOYEN_ANNEE_ACADEMIE  TAUX_ADMISSION  DEFAUT_PAIEMENT_2ANNEES  \
# 202                         NaN             NaN                    0.009
# 3287                        NaN             NaN                    0.016
# 5467                        NaN             1.0                      NaN
# 3225                        NaN             NaN                    0.033
# 5047                        NaN             NaN                    0.000
# 4542                        NaN             NaN                      NaN
# 311                         NaN             NaN                    0.030
# 296                         NaN             NaN                    0.011
#
#       DEFAUT_PAIEMENT_3ANNEES
# 202                     0.010
# 3287                    0.005
# 5467                      NaN
# 3225                    0.024
# 5047                    0.142
# 4542                      NaN
# 311                     0.050
# 296                     0.032

# %% [markdown]
# **Commentaire**:
#
# On va transformer ces lignes en nan

# %%
# la colonne contient une valeur string ce qui empêche la conversion en entier
df.loc[df['NOMBRE_ETUDIANTS'] == 'PrivacySuppressed', 'NOMBRE_ETUDIANTS'] = np.nan
df.loc[df['AGE_ENTREE'] == 'PrivacySuppressed', 'AGE_ENTREE'] = np.nan
#convertir ces varaible en float
df['NOMBRE_ETUDIANTS'] = pd.to_numeric(df['NOMBRE_ETUDIANTS'])
df['AGE_ENTREE'] = np.round(pd.to_numeric(df['AGE_ENTREE']), 2)

# %%
df.dtypes
# Out:
# VILLE                         object
# NOMBRE_ETUDIANTS             float64
# AGE_ENTREE                   float64
# COUT_MOYEN_ANNEE_ACADEMIE    float64
# TAUX_ADMISSION               float64
# DEFAUT_PAIEMENT_2ANNEES      float64
# DEFAUT_PAIEMENT_3ANNEES      float64
# dtype: object

# %%
((df.isna().sum()/ df.shape[0])*100).sort_values()
# Out:
# VILLE                         0.000000
# AGE_ENTREE                   10.000000
# NOMBRE_ETUDIANTS             12.333333
# DEFAUT_PAIEMENT_3ANNEES      18.000000
# DEFAUT_PAIEMENT_2ANNEES      19.333333
# COUT_MOYEN_ANNEE_ACADEMIE    52.333333
# TAUX_ADMISSION               72.000000
# dtype: float64

# %%
df_num = df.select_dtypes(include =['float', 'int'])

# %%
imputer = mice.MICEData(df_num)
imputed_data = imputer.data

# %%
imputed_data.head(2)
# Out:
#    NOMBRE_ETUDIANTS  AGE_ENTREE  COUT_MOYEN_ANNEE_ACADEMIE  TAUX_ADMISSION  \
# 0           13484.0       33.36                    24836.0          0.7347
# 1            5340.0       20.54                    17166.0          0.6065
#
#    DEFAUT_PAIEMENT_2ANNEES  DEFAUT_PAIEMENT_3ANNEES
# 0                    0.105                    0.104
# 1                    0.086                    0.080

# %%
imputed_data.isna().sum()
# Out:
# NOMBRE_ETUDIANTS             0
# AGE_ENTREE                   0
# COUT_MOYEN_ANNEE_ACADEMIE    0
# TAUX_ADMISSION               0
# DEFAUT_PAIEMENT_2ANNEES      0
# DEFAUT_PAIEMENT_3ANNEES      0
# dtype: int64

# %% [markdown]
# ### Visualisation avant et après imputation

# %%
plt.figure(figsize=(16, 6))
plot_dist(df, color = 'red', n_col = 3 , n_rows =2 )
plot_dist(imputed_data, color = 'blue',  n_col = 3 , n_rows =2)
# Out:
# 6it [00:00, 18.78it/s]
# 6it [00:00, 56.86it/s]

# %% [markdown]
# **Commentaire** :
#
# * Vous voyez à quel point cette methode est puissante, plus le taux le valeurs manquantes est faible, plus l'estimation est précise. C'est incroyable.
#
#
# * Nos variable **taux_admisssion** et **COUT_MOYEN_ANNEE_ACADEMIE** ont des taux de nan de **72%** et **52%** respectivement. Et vous voyez malgré tout, comment, elle ajuste ses estimations.

# %% [markdown]
# ### Vérification statistique avant et après imputation

# %%
df.describe().T
# Out:
#                            count          mean           std        min  \
# NOMBRE_ETUDIANTS           263.0   1718.425856   4823.586022    11.0000
# AGE_ENTREE                 270.0     25.894111      3.845233    17.8800
# COUT_MOYEN_ANNEE_ACADEMIE  143.0  24801.076923  14500.224006  5810.0000
# TAUX_ADMISSION              84.0      0.734923      0.186207     0.2438
# DEFAUT_PAIEMENT_2ANNEES    242.0      0.088202      0.068284     0.0000
# DEFAUT_PAIEMENT_3ANNEES    246.0      0.110894      0.069208     0.0000
#
#                                     25%          50%          75%        max
# NOMBRE_ETUDIANTS             100.500000    390.00000   1452.50000  62648.000
# AGE_ENTREE                    23.275000     25.66500     28.36500     40.290
# COUT_MOYEN_ANNEE_ACADEMIE  13612.000000  21278.00000  29494.00000  67638.000
# TAUX_ADMISSION                 0.644375      0.74605      0.90375      1.000
# DEFAUT_PAIEMENT_2ANNEES        0.035000      0.08300      0.13575      0.425
# DEFAUT_PAIEMENT_3ANNEES        0.056000      0.10400      0.15075      0.333

# %%
imputed_data.describe().T
# Out:
#                            count          mean           std        min  \
# NOMBRE_ETUDIANTS           292.0   1717.291096   4576.930319    11.0000
# AGE_ENTREE                 292.0     25.891541      3.697036    17.8800
# COUT_MOYEN_ANNEE_ACADEMIE  292.0  24818.897260  10129.150790  5810.0000
# TAUX_ADMISSION             292.0      0.734764      0.099447     0.2438
# DEFAUT_PAIEMENT_2ANNEES    292.0      0.088168      0.062142     0.0000
# DEFAUT_PAIEMENT_3ANNEES    292.0      0.110911      0.063503     0.0000
#
#                                    25%         50%          75%        max
# NOMBRE_ETUDIANTS             121.00000    499.5000   1707.00000  62648.000
# AGE_ENTREE                    23.47500     25.8600     27.97750     40.290
# COUT_MOYEN_ANNEE_ACADEMIE  21388.25000  24836.0000  24836.00000  67638.000
# TAUX_ADMISSION                 0.73470      0.7347      0.73470      1.000
# DEFAUT_PAIEMENT_2ANNEES        0.04175      0.0880      0.12000      0.425
# DEFAUT_PAIEMENT_3ANNEES        0.06575      0.1110      0.14025      0.333

# %% [markdown]
# **Commentaire** :
#
# Une autre façon de comparer avant et après l'imputation et de regarder les élèments statistiques.
#
# Et on voit bien que **mean** et **median** (50%) sont quasiment restés intactes.
#
# On peut aussi regarder les boxplot pour la comparaison.
